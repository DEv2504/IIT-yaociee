# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.naive_bayes import GaussianNB

# %%
#Reading CSV files
df= pd.read_csv('train_x.CSV')
df
# Out:
#           Hour 0: Summary Hour 0: Precip Type  Hour 0: Humidity  \
# 0           Partly Cloudy                rain              0.81
# 1                   Clear                snow              0.92
# 2      Windy and Overcast                rain              0.93
# 3           Partly Cloudy                rain              0.49
# 4           Mostly Cloudy                rain              0.89
# ...                   ...                 ...               ...
# 77153               Foggy                rain              1.00
# 77154       Mostly Cloudy                rain              0.93
# 77155       Partly Cloudy                rain              0.89
# 77156       Mostly Cloudy                snow              0.96
# 77157       Mostly Cloudy                rain              0.93
#
#        Hour 0: Wind Speed (km/h)  Hour 0: Wind Bearing (degrees)  \
# 0                      12.582479                       12.291079
# ...

# %%
#Encoding the strings to the Numericals
Numercials=LabelEncoder()

# %%
# Dropping the target variable and make it is a new frame
inputs=df.drop('Hour 0: Summary', axis='columns')
target=df['Hour 0: Summary']
target
# Out:
# 0             Partly Cloudy
# 1                     Clear
# 2        Windy and Overcast
# 3             Partly Cloudy
# 4             Mostly Cloudy
#                 ...
# 77153                 Foggy
# 77154         Mostly Cloudy
# 77155         Partly Cloudy
# 77156         Mostly Cloudy
# 77157         Mostly Cloudy
# Name: Hour 0: Summary, Length: 77158, dtype: object

# %%
# Applying the Gaussian naivesbayes
Classifier=GaussianNB()
Classifier.fit(,target)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11320\2878094512.py in ?()
#       1 # Applying the Gaussian naivesbayes
#       2 Classifier=GaussianNB()
# ----> 3 Classifier.fit(df,target)
#
# G:\python engine\lib\site-packages\sklearn\base.py in ?(estimator, *args, **kwargs)
#    1470                 skip_parameter_validation=(
#    1471                     prefer_skip_nested_validation or global_skip_validation
#    1472                 )
#    1473             ):
# -> 1474                 return fit_method(estimator, *args, **kwargs)
#
# G:\python engine\lib\site-packages\sklearn\naive_bayes.py in ?(self, X, y, sample_weight)
#     259         self : object
#     260             Returns the instance itself.
#     261         """
#     262         y = self._validate_data(y=y)
# --> 263         return self._partial_fit(
# ...
